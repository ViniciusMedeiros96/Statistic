# %% [markdown]
# # Atividade Semana 2
# ## Vinícius Celestino de Medeiros

# %%
### Questão 1

# %% [markdown]
# `Lista` = São mutáveis, ordenadas, heterogêneas, indexada por posição, delimitada por colchetes. Podemos acessar itens através de seu índice, que corresponde a sua posição na lista.
#
# `Dicionário` = São mutáveis, não ordenados, heterogêneos, indexada por chaves, delimitada por chaves {}. É possível acessar dados em um dicionário através da palavra chave que foi associada a um elemento.
#
# `Array Numpy` = O array numpy é uma estrutura de dados com capacidade de vetorização, que possibilita que qualquer operação feita com a estrutura seja feita elemento a elemento sem a necessidade de um laço para acessar esses elementos, tornando, assim, a operação computacionalmente mais eficiente.
#
# `Series pandas` = É também uma estrutura de dados 1D na qual podemos juntar listas e/ou dicionários com a finalidade de criar uma tabela de dados com essa união.

# %% [markdown]
# ### Questão 2

# %%
import pandas as pd
import numpy as np

# %%
ser = pd.Series(np.random.randint(1, 10, 35))

# %%
ser
# Out:
# 0     7
# 1     6
# 2     3
# 3     3
# 4     3
# 5     1
# 6     6
# 7     4
# 8     1
# 9     9
# 10    5
# 11    5
# 12    4
# 13    4
# 14    9
# 15    8
# 16    1
# 17    7
# 18    7
# 19    5
# 20    8
# 21    7
# 22    6
# 23    4
# 24    7
# 25    3
# 26    9
# 27    9
# 28    9
# 29    4
# 30    6
# 31    7
# 32    2
# 33    3
# 34    3
# dtype: int32

# %%
ser = pd.DataFrame(np.random.randint(0,34, size=(7,5)),columns=list("12345"))

# %%
print(ser[0:2])
ser
# Out:
#     1  2   3   4   5
# 0  27  6   3  31  10
# 1  17  4  11  30  25
#     1   2   3   4   5
# 0  27   6   3  31  10
# 1  17   4  11  30  25
# 2  20  20   9   6   5
# 3   6  16   8  11  25
# 4   9  22  14   0  20
# 5   8  12  26   2  21
# 6   6  28  32  33  29

# %% [markdown]
# ### Questão 3

# %%
import pandas as pd

# %%
file = "https://raw.githubusercontent.com/selva86/datasets/master/BostonHousing.csv"

# %%
name_files = ["crim", "medv"]

# %%
newfile = pd.read_csv(file, usecols=name_files)

# %%
newfile.head()
# Out:
#       crim  medv
# 0  0.00632  24.0
# 1  0.02731  21.6
# 2  0.02729  34.7
# 3  0.03237  33.4
# 4  0.06905  36.2

# %% [markdown]
# ### Questão 4

# %%
import pandas as pd

# %%
file = "https://raw.githubusercontent.com/selva86/datasets/master/Cars93_miss.csv"

# %%
new_file = pd.read_csv(file)
new_file.rename(columns={'Type': 'DataType'}, inplace = True)
new_file
# Out:
#    Manufacturer    Model DataType  Min.Price  Price  Max.Price  MPG.city  \
# 0         Acura  Integra    Small       12.9   15.9       18.8      25.0
# 1           NaN   Legend  Midsize       29.2   33.9       38.7      18.0
# 2          Audi       90  Compact       25.9   29.1       32.3      20.0
# 3          Audi      100  Midsize        NaN   37.7       44.6      19.0
# 4           BMW     535i  Midsize        NaN   30.0        NaN      22.0
# ..          ...      ...      ...        ...    ...        ...       ...
# 88   Volkswagen  Eurovan      Van       16.6   19.7       22.7      17.0
# 89   Volkswagen   Passat  Compact       17.6   20.0       22.4      21.0
# 90   Volkswagen  Corrado   Sporty       22.9   23.3       23.7      18.0
# 91        Volvo      240  Compact       21.8   22.7       23.5      21.0
# 92          NaN      850  Midsize       24.8   26.7       28.5      20.0
#
#     MPG.highway             AirBags DriveTrain  ... Passengers  Length  \
# ...

# %% [markdown]
# ### Questão 5

# %%
import pandas as pd

# %%
file = 'https://raw.githubusercontent.com/selva86/datasets/master/Cars93_miss.csv'
new_file = pd.read_csv(file)
new_file.info()
print("Valor nulos:",new_file.isnull().sum().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93 entries, 0 to 92
# Data columns (total 27 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Manufacturer        89 non-null     object
#  1   Model               92 non-null     object
#  2   Type                90 non-null     object
#  3   Min.Price           86 non-null     float64
#  4   Price               91 non-null     float64
#  5   Max.Price           88 non-null     float64
#  6   MPG.city            84 non-null     float64
#  7   MPG.highway         91 non-null     float64
#  8   AirBags             87 non-null     object
#  9   DriveTrain          86 non-null     object
#  10  Cylinders           88 non-null     object
#  11  EngineSize          91 non-null     float64
#  12  Horsepower          86 non-null     float64
#  13  RPM                 90 non-null     float64
#  14  Rev.per.mile        87 non-null     float64
# ...

# %% [markdown]
# ### Questão 6

# %%
file = 'https://raw.githubusercontent.com/selva86/datasets/master/Cars93_miss.csv'
new_file = pd.read_csv(file)
new_file

# %%
print(pd.isnull(new_file).sum().max())
print("Coluna com mais valores ausentes:",pd.isnull(new_file).sum().idxmax())

# %% [markdown]
# ### Questão 7

# %%
new_file = pd.DataFrame(np.arange(20).reshape(-1, 5), columns=list('abcde'))
new_file
# Out:
#     a   b   c   d   e
# 0   0   1   2   3   4
# 1   5   6   7   8   9
# 2  10  11  12  13  14
# 3  15  16  17  18  19

# %%
new_file = pd.DataFrame(new_file["a"])
new_file
# Out:
#     a
# 0   0
# 1   5
# 2  10
# 3  15

# %%
new_file["a"].to_frame()
# Out:
#     a
# 0   0
# 1   5
# 2  10
# 3  15

# %% [markdown]
# ### Questão 8

# %%
import pandas as pd

# %% [markdown]
# #### A)

# %%
print("original")
df = pd.DataFrame(np.arange(20).reshape(-1, 5), columns=list('abcde'))
df
# Out:
# original
#     a   b   c   d   e
# 0   0   1   2   3   4
# 1   5   6   7   8   9
# 2  10  11  12  13  14
# 3  15  16  17  18  19

# %%
print("nova")
df = df[["c","b","a","d","e"]]
df
# Out:
# nova
#     c   b   a   d   e
# 0   2   1   0   3   4
# 1   7   6   5   8   9
# 2  12  11  10  13  14
# 3  17  16  15  18  19

# %% [markdown]
# #### C)

# %%
print("original")
df = pd.DataFrame(np.arange(20).reshape(-1, 5), columns=list('abcde'))
df
# Out:
# original
#     a   b   c   d   e
# 0   0   1   2   3   4
# 1   5   6   7   8   9
# 2  10  11  12  13  14
# 3  15  16  17  18  19

# %%
df = pd.DataFrame(np.arange(20).reshape(-1, 5), columns=list('abcde'))
df_reverse = df.columns.tolist()
df_reverse.sort(reverse=True)
df = df[df_reverse]
print("novo")
df
# Out:
# novo
#     e   d   c   b   a
# 0   4   3   2   1   0
# 1   9   8   7   6   5
# 2  14  13  12  11  10
# 3  19  18  17  16  15

# %% [markdown]
# ### Questão 9

# %%
file = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/Cars93_miss.csv')
print("original")
file
# Out:
# original
#    Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0         Acura  Integra    Small       12.9   15.9       18.8      25.0
# 1           NaN   Legend  Midsize       29.2   33.9       38.7      18.0
# 2          Audi       90  Compact       25.9   29.1       32.3      20.0
# 3          Audi      100  Midsize        NaN   37.7       44.6      19.0
# 4           BMW     535i  Midsize        NaN   30.0        NaN      22.0
# ..          ...      ...      ...        ...    ...        ...       ...
# 88   Volkswagen  Eurovan      Van       16.6   19.7       22.7      17.0
# 89   Volkswagen   Passat  Compact       17.6   20.0       22.4      21.0
# 90   Volkswagen  Corrado   Sporty       22.9   23.3       23.7      18.0
# 91        Volvo      240  Compact       21.8   22.7       23.5      21.0
# 92          NaN      850  Midsize       24.8   26.7       28.5      20.0
#
#     MPG.highway             AirBags DriveTrain  ... Passengers  Length  \
# ...

# %%
print("novo")
file.iloc[0:10,:10]
# Out:
# novo
#   Manufacturer       Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0        Acura     Integra    Small       12.9   15.9       18.8      25.0
# 1          NaN      Legend  Midsize       29.2   33.9       38.7      18.0
# 2         Audi          90  Compact       25.9   29.1       32.3      20.0
# 3         Audi         100  Midsize        NaN   37.7       44.6      19.0
# 4          BMW        535i  Midsize        NaN   30.0        NaN      22.0
# 5        Buick     Century  Midsize       14.2   15.7       17.3      22.0
# 6        Buick     LeSabre    Large       19.9   20.8        NaN      19.0
# 7        Buick  Roadmaster    Large       22.6   23.7       24.9      16.0
# 8        Buick     Riviera  Midsize       26.3   26.3       26.3      19.0
# 9     Cadillac     DeVille    Large       33.0   34.7       36.3      16.0
#
#    MPG.highway             AirBags DriveTrain
# 0         31.0                None      Front
# ...

# %% [markdown]
# ### Questão 10

# %%
file =pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/Cars93_miss.csv')
# Out:
#    Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0         Acura  Integra    Small       12.9   15.9       18.8      25.0
# 1           NaN   Legend  Midsize       29.2   33.9       38.7      18.0
# 2          Audi       90  Compact       25.9   29.1       32.3      20.0
# 3          Audi      100  Midsize        NaN   37.7       44.6      19.0
# 4           BMW     535i  Midsize        NaN   30.0        NaN      22.0
# ..          ...      ...      ...        ...    ...        ...       ...
# 88   Volkswagen  Eurovan      Van       16.6   19.7       22.7      17.0
# 89   Volkswagen   Passat  Compact       17.6   20.0       22.4      21.0
# 90   Volkswagen  Corrado   Sporty       22.9   23.3       23.7      18.0
# 91        Volvo      240  Compact       21.8   22.7       23.5      21.0
# 92          NaN      850  Midsize       24.8   26.7       28.5      20.0
#
#     MPG.highway             AirBags DriveTrain  ... Passengers  Length  \
# ...

# %%
file[["Manufacturer","Model","Type"]].iloc[0:20]
# Out:
#    Manufacturer       Model     Type
# 0         Acura     Integra    Small
# 1           NaN      Legend  Midsize
# 2          Audi          90  Compact
# 3          Audi         100  Midsize
# 4           BMW        535i  Midsize
# 5         Buick     Century  Midsize
# 6         Buick     LeSabre    Large
# 7         Buick  Roadmaster    Large
# 8         Buick     Riviera  Midsize
# 9      Cadillac     DeVille    Large
# 10     Cadillac     Seville  Midsize
# 11    Chevrolet    Cavalier  Compact
# 12    Chevrolet     Corsica  Compact
# 13    Chevrolet      Camaro   Sporty
# 14    Chevrolet      Lumina  Midsize
# 15    Chevrolet  Lumina_APV      Van
# 16    Chevrolet       Astro      Van
# 17    Chevrolet     Caprice    Large
# 18    Chevrolet    Corvette   Sporty
# 19          NaN    Concorde    Large

# %% [markdown]
# ### Questão 11

# %%
df = pd.DataFrame(np.random.randint(10, 40, 60).reshape(-1, 4))

# %%
print("Original:")
print(df)
maior_100 = df[df.sum(axis=1) > 100]
print("------------------")
print("Novo:")
maior_100.iloc[-2:]
# Out:
# Original:
#     0   1   2   3   4
# 0   0   1   2   3   4
# 1   5   6   7   8   9
# 2  10  11  12  13  14
# 3  15  16  17  18  19
# 4  20  21  22  23  24
# ------------------
# Novo:
#     0   1   2   3   4
# 4  20  21  22  23  24

# %% [markdown]
# ### **Questão 12**

# %%
df = pd.DataFrame(np.arange(25).reshape(5, -1))
print(df)
# Out:
#     0   1   2   3   4
# 0   0   1   2   3   4
# 1   5   6   7   8   9
# 2  10  11  12  13  14
# 3  15  16  17  18  19
# 4  20  21  22  23  24

# %%
df.at[1] = [0,1,2,3,4]
df.at[0] = [5,6,7,8,9]

# %%
def
# Out:
#     0   1   2   3   4
# 0   5   6   7   8   9
# 1   0   1   2   3   4
# 2  10  11  12  13  14
# 3  15  16  17  18  19
# 4  20  21  22  23  24
