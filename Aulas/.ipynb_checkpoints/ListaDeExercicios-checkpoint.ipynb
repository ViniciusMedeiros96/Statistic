# %% [markdown]
# ### Questão 2

# %%
import pandas as pd
import numpy as np

# %%
ser = pd.Series(np.random.randint(1, 10, 35))

# %%
serie = pd.DataFrame(ser)

# %%
df = pd.DataFrame(np.random.randint(0,34, size=(7,5)),columns=list("12345"))

# %%
df
# Out:
#     1   2   3   4   5
# 0  17  14   8  28  28
# 1  32  30  16   7   0
# 2  33  31  31  33  26
# 3  24  23   4  18   5
# 4  23  22  14  24  17
# 5  31   7  28  16  27
# 6  27  11   1  25   7

# %% [markdown]
# ### Questão 3

# %%
import pandas as pd

# %%
file = "https://raw.githubusercontent.com/selva86/datasets/master/BostonHousing.csv"

# %%
name_files = ["crim", "medv"]

# %%
newfile = pd.read_csv(file, usecols=name_files)

# %%
newfile.head()
# Out:
#       crim  medv
# 0  0.00632  24.0
# 1  0.02731  21.6
# 2  0.02729  34.7
# 3  0.03237  33.4
# 4  0.06905  36.2

# %% [markdown]
# ### Questão 4

# %%
import pandas as pd

# %%
file = "https://raw.githubusercontent.com/selva86/datasets/master/Cars93_miss.csv"

# %%
new_file = pd.read_csv(file)
new_file.rename(columns={'Type': 'DataType'}, inplace = True)
new_file
# Out:
#    Manufacturer    Model DataType  Min.Price  Price  Max.Price  MPG.city  \
# 0         Acura  Integra    Small       12.9   15.9       18.8      25.0
# 1           NaN   Legend  Midsize       29.2   33.9       38.7      18.0
# 2          Audi       90  Compact       25.9   29.1       32.3      20.0
# 3          Audi      100  Midsize        NaN   37.7       44.6      19.0
# 4           BMW     535i  Midsize        NaN   30.0        NaN      22.0
# ..          ...      ...      ...        ...    ...        ...       ...
# 88   Volkswagen  Eurovan      Van       16.6   19.7       22.7      17.0
# 89   Volkswagen   Passat  Compact       17.6   20.0       22.4      21.0
# 90   Volkswagen  Corrado   Sporty       22.9   23.3       23.7      18.0
# 91        Volvo      240  Compact       21.8   22.7       23.5      21.0
# 92          NaN      850  Midsize       24.8   26.7       28.5      20.0
#
#     MPG.highway             AirBags DriveTrain  ... Passengers  Length  \
# ...

# %% [markdown]
# ### Questão 5

# %%
import panda as pd

# %%
file = 'https://raw.githubusercontent.com/selva86/datasets/master/Cars93_miss.csv'
new_file = pd.read_csv(file)
new_file.info()
print("Valor nulos:",new_file.isnull().sum().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93 entries, 0 to 92
# Data columns (total 27 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Manufacturer        89 non-null     object
#  1   Model               92 non-null     object
#  2   Type                90 non-null     object
#  3   Min.Price           86 non-null     float64
#  4   Price               91 non-null     float64
#  5   Max.Price           88 non-null     float64
#  6   MPG.city            84 non-null     float64
#  7   MPG.highway         91 non-null     float64
#  8   AirBags             87 non-null     object
#  9   DriveTrain          86 non-null     object
#  10  Cylinders           88 non-null     object
#  11  EngineSize          91 non-null     float64
#  12  Horsepower          86 non-null     float64
#  13  RPM                 90 non-null     float64
#  14  Rev.per.mile        87 non-null     float64
# ...

# %% [markdown]
# ### Questão 6

# %%
file = 'https://raw.githubusercontent.com/selva86/datasets/master/Cars93_miss.csv'
new_file = pd.read_csv(file)
new_file
# Out:
#    Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0         Acura  Integra    Small       12.9   15.9       18.8      25.0
# 1           NaN   Legend  Midsize       29.2   33.9       38.7      18.0
# 2          Audi       90  Compact       25.9   29.1       32.3      20.0
# 3          Audi      100  Midsize        NaN   37.7       44.6      19.0
# 4           BMW     535i  Midsize        NaN   30.0        NaN      22.0
# ..          ...      ...      ...        ...    ...        ...       ...
# 88   Volkswagen  Eurovan      Van       16.6   19.7       22.7      17.0
# 89   Volkswagen   Passat  Compact       17.6   20.0       22.4      21.0
# 90   Volkswagen  Corrado   Sporty       22.9   23.3       23.7      18.0
# 91        Volvo      240  Compact       21.8   22.7       23.5      21.0
# 92          NaN      850  Midsize       24.8   26.7       28.5      20.0
#
#     MPG.highway             AirBags DriveTrain  ... Passengers  Length  \
# ...

# %%
print(pd.isnull(new_file).sum().max())
print("Coluna com mais valores ausentes:",pd.isnull(new_file).sum().idxmax())
# Out:
# Manufacturer          True
# Model                 True
# Type                  True
# Min.Price             True
# Price                 True
# Max.Price             True
# MPG.city              True
# MPG.highway           True
# AirBags               True
# DriveTrain            True
# Cylinders             True
# EngineSize            True
# Horsepower            True
# RPM                   True
# Rev.per.mile          True
# Man.trans.avail       True
# Fuel.tank.capacity    True
# Passengers            True
# Length                True
# Wheelbase             True
# Width                 True
# Turn.circle           True
# Rear.seat.room        True
# Luggage.room          True
# Weight                True
# Origin                True
# Make                  True
# dtype: bool
# Coluna com mais valores ausentes: Luggage.room

# %% [markdown]
# ### Questão 7

# %%
new_file = pd.DataFrame(np.arange(20).reshape(-1, 5), columns=list('abcde'))
new_file
# Out:
#     a   b   c   d   e
# 0   0   1   2   3   4
# 1   5   6   7   8   9
# 2  10  11  12  13  14
# 3  15  16  17  18  19

# %%
new_file = pd.DataFrame(new_file["a"])
new_file
# Out:
#     a
# 0   0
# 1   5
# 2  10
# 3  15

# %%
new_file = pd.DataFrame(np.arange(20).reshape(-1, 5), columns=list('abcde'))
new_file
# Out:
#     e   b   c   d   a
# 0   0   1   2   3   4
# 1   5   6   7   8   9
# 2  10  11  12  13  14
# 3  15  16  17  18  19
