# %%
import pandas as pd
import numpy as np

# %%
dados_2019 = pd.read_excel(r'c:\Users\vinim\Desktop\datatran2019.xlsx')
#dados_2020 = pd.read_excel(r'c:\Users\vinim\Desktop\datatran2020.xlsx')
dados_2019
# Out:
#            id data_inversa     dia_semana   horario  uf     br     km  \
# 0      182210   2019-01-01    terça-feira  01:30:00  SP  116.0  218.0
# 1      182211   2019-01-01    terça-feira  01:30:00  PR  373.0  177.3
# 2      182212   2019-01-01    terça-feira  00:45:00  SC  101.0   16.0
# 3      182214   2019-01-01    terça-feira  00:00:00  CE   20.0  429.5
# 4      182215   2019-01-01    terça-feira  01:00:00  MG  381.0  327.0
# ...       ...          ...            ...       ...  ..    ...    ...
# 67441  266255   2019-10-07  segunda-feira  09:10:00  ES  101.0  270.5
# 67442  266406   2019-11-25  segunda-feira  07:20:00  PR  116.0  125.0
# 67443  266434   2019-06-03  segunda-feira  19:00:00  CE  222.0    1.4
# 67444  266573   2019-07-13         sábado  19:35:00  PR  373.0  425.0
# 67445  266627   2019-10-22    terça-feira  20:20:00  BA  324.0  608.0
#
#                 municipio                       causa_acidente  \
# ...

# %%
#dados_2019.shape
#dados_2019.info()
#dados_2019.iloc[:,20]

# %%
#dados_2019['municipio'].value_counts().head()

# %%
#acidentes_graves = dados_2019[dados_2019.sum(axis=1) >= 1]

# %%
#print(acidentes_graves)

# %%
#acidente_estado_2019 = pd.DataFrame(dados_2019)
acidente_estado_2019 = acidente_estado_2019.sort_values(by="uf")
acidente_estado_2019
# Out:
#            id data_inversa     dia_semana   horario  uf     br     km  \
# 63891  256333   2019-12-15        domingo  17:00:00  AC  364.0  129.0
# 9489   193900   2019-02-27   quarta-feira  09:30:00  AC  364.0  122.0
# 50071  240574   2019-09-25   quarta-feira  14:30:00  AC  317.0  210.0
# 9832   194294   2019-03-01    sexta-feira  08:20:00  AC  364.0  123.0
# 51649  242338   2019-10-14  segunda-feira  08:00:00  AC  317.0  195.0
# ...       ...          ...            ...       ...  ..    ...    ...
# 35575  223627   2019-07-21        domingo  20:10:00  TO  153.0  471.0
# 7698   191820   2019-02-16         sábado  22:15:00  TO  153.0  526.3
# 60769  252939   2019-11-30         sábado  19:15:00  TO  153.0  560.8
# 60768  252938   2019-11-30         sábado  18:10:00  TO  153.0  446.9
# 24697  211238   2019-05-23   quinta-feira  07:10:00  TO  153.0  192.0
#
#          municipio                                     causa_acidente  \
# ...

# %%
#dados_2020.shape
#dados_2020.info()
#dados_2020.iloc[:,20].sum()

# %%
#dados_2020['municipio'].value_counts().head()
